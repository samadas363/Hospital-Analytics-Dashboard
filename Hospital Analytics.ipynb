# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
df  = pd.read_csv(r"C:\Users\AM HK\Documents\hospital_analytics.csv")

# %%
df.head()
# Out:
#   Patient_ID    Patient_Name  Age  Gender  Department Admission_Date  \
# 0    P100001  Patient_100001   24  Female   Neurology     2026-06-14
# 1    P100002  Patient_100002   82  Female   Maternity     2026-06-15
# 2    P100003  Patient_100003   29    Male  Cardiology     2026-07-26
# 3    P100004  Patient_100004   33  Female   Emergency     2026-05-20
# 4    P100005  Patient_100005   26    Male    Oncology     2026-04-26
#
#   Discharge_Date Admission_Type        Diagnosis      Treatment      Doctor  \
# 0     2026-06-17      Emergency         Diabetes  Physiotherapy  Dr. Fatima
# 1     2026-06-22      Emergency     Appendicitis    Observation   Dr. Imran
# 2     2026-07-28       Elective         Fracture    Observation   Dr. Usman
# 3     2026-05-24      Emergency  Routine Checkup     Medication   Dr. Usman
# 4     2026-04-30       Elective    Heart Disease     Medication  Dr. Fatima
#
#   Hospital_Branch        Insurance_Type  Treatment_Cost  Length_of_Stay  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Patient_ID    Patient_Name  Age  Gender   Department Admission_Date  \
# 0       P100001  Patient_100001   24  Female    Neurology     2026-06-14
# 1       P100002  Patient_100002   82  Female    Maternity     2026-06-15
# 2       P100003  Patient_100003   29    Male   Cardiology     2026-07-26
# 3       P100004  Patient_100004   33  Female    Emergency     2026-05-20
# 4       P100005  Patient_100005   26    Male     Oncology     2026-04-26
# ...         ...             ...  ...     ...          ...            ...
# 4995    P104996  Patient_104996   50  Female    Maternity     2026-06-25
# 4996    P104997  Patient_104997   45  Female     Oncology     2026-08-03
# 4997    P104998  Patient_104998   41    Male   Cardiology     2026-05-06
# 4998    P104999  Patient_104999   42    Male  Orthopedics     2026-07-24
# 4999    P105000  Patient_105000   58    Male  Orthopedics     2026-05-31
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5000, 22)

# %%
df.isnull().sum()
# Out:
# Patient_ID               0
# Patient_Name             0
# Age                      0
# Gender                   0
# Department               0
# Admission_Date           0
# Discharge_Date           0
# Admission_Type           0
# Diagnosis                0
# Treatment                0
# Doctor                   0
# Hospital_Branch          0
# Insurance_Type          25
# Treatment_Cost           0
# Length_of_Stay           0
# Patient_Satisfaction    25
# Outcome                  0
# Age_Group                0
# Admission_Month          0
# Admission_Month_Num      0
# Admission_Week           0
# Day_of_Week              0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_percentage
# Out:
# Patient_ID              0.0
# Patient_Name            0.0
# Age                     0.0
# Gender                  0.0
# Department              0.0
# Admission_Date          0.0
# Discharge_Date          0.0
# Admission_Type          0.0
# Diagnosis               0.0
# Treatment               0.0
# Doctor                  0.0
# Hospital_Branch         0.0
# Insurance_Type          0.5
# Treatment_Cost          0.0
# Length_of_Stay          0.0
# Patient_Satisfaction    0.5
# Outcome                 0.0
# Age_Group               0.0
# Admission_Month         0.0
# Admission_Month_Num     0.0
# Admission_Week          0.0
# Day_of_Week             0.0
# dtype: float64

# %%
missing_percentage = (
    df.isnull().sum()
    .div(len(df))
    .mul(100)
    .round(2)
)

missing_percentage
# Out:
# Patient_ID              0.0
# Patient_Name            0.0
# Age                     0.0
# Gender                  0.0
# Department              0.0
# Admission_Date          0.0
# Discharge_Date          0.0
# Admission_Type          0.0
# Diagnosis               0.0
# Treatment               0.0
# Doctor                  0.0
# Hospital_Branch         0.0
# Insurance_Type          0.5
# Treatment_Cost          0.0
# Length_of_Stay          0.0
# Patient_Satisfaction    0.5
# Outcome                 0.0
# Age_Group               0.0
# Admission_Month         0.0
# Admission_Month_Num     0.0
# Admission_Week          0.0
# Day_of_Week             0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Patient_ID            5000 non-null   str
#  1   Patient_Name          5000 non-null   str
#  2   Age                   5000 non-null   int64
#  3   Gender                5000 non-null   str
#  4   Department            5000 non-null   str
#  5   Admission_Date        5000 non-null   str
#  6   Discharge_Date        5000 non-null   str
#  7   Admission_Type        5000 non-null   str
#  8   Diagnosis             5000 non-null   str
#  9   Treatment             5000 non-null   str
#  10  Doctor                5000 non-null   str
#  11  Hospital_Branch       5000 non-null   str
#  12  Insurance_Type        4975 non-null   str
#  13  Treatment_Cost        5000 non-null   float64
#  14  Length_of_Stay        5000 non-null   int64
#  15  Patient_Satisfaction  4975 non-null   float64
# ...

# %%
df.dtypes
# Out:
# Patient_ID                  str
# Patient_Name                str
# Age                       int64
# Gender                      str
# Department                  str
# Admission_Date              str
# Discharge_Date              str
# Admission_Type              str
# Diagnosis                   str
# Treatment                   str
# Doctor                      str
# Hospital_Branch             str
# Insurance_Type              str
# Treatment_Cost          float64
# Length_of_Stay            int64
# Patient_Satisfaction    float64
# Outcome                     str
# Age_Group                   str
# Admission_Month             str
# Admission_Month_Num       int64
# Admission_Week            int64
# Day_of_Week                 str
# dtype: object

# %%
df.head(5)
# Out:
#   Patient_ID    Patient_Name  Age  Gender  Department Admission_Date  \
# 0    P100001  Patient_100001   24  Female   Neurology     2026-06-14
# 1    P100002  Patient_100002   82  Female   Maternity     2026-06-15
# 2    P100003  Patient_100003   29    Male  Cardiology     2026-07-26
# 3    P100004  Patient_100004   33  Female   Emergency     2026-05-20
# 4    P100005  Patient_100005   26    Male    Oncology     2026-04-26
#
#   Discharge_Date Admission_Type        Diagnosis      Treatment      Doctor  \
# 0     2026-06-17      Emergency         Diabetes  Physiotherapy  Dr. Fatima
# 1     2026-06-22      Emergency     Appendicitis    Observation   Dr. Imran
# 2     2026-07-28       Elective         Fracture    Observation   Dr. Usman
# 3     2026-05-24      Emergency  Routine Checkup     Medication   Dr. Usman
# 4     2026-04-30       Elective    Heart Disease     Medication  Dr. Fatima
#
#   Hospital_Branch        Insurance_Type  Treatment_Cost  Length_of_Stay  \
# ...

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# Patient_ID              0.0
# Patient_Name            0.0
# Age                     0.0
# Gender                  0.0
# Department              0.0
# Admission_Date          0.0
# Discharge_Date          0.0
# Admission_Type          0.0
# Diagnosis               0.0
# Treatment               0.0
# Doctor                  0.0
# Hospital_Branch         0.0
# Insurance_Type          0.5
# Treatment_Cost          0.0
# Length_of_Stay          0.0
# Patient_Satisfaction    0.5
# Outcome                 0.0
# Age_Group               0.0
# Admission_Month         0.0
# Admission_Month_Num     0.0
# Admission_Week          0.0
# Day_of_Week             0.0
# dtype: float64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Patient_ID    Patient_Name  Age  Gender        Department Admission_Date  \
# 6       P100007  Patient_100007   57  Female         Neurology     2026-07-20
# 123     P100124  Patient_100124   79  Female         Maternity     2026-08-16
# 152     P100153  Patient_100153   64  Female  General Medicine     2026-06-01
# 155     P100156  Patient_100156   74  Female          Oncology     2026-05-09
# 243     P100244  Patient_100244   42    Male        Cardiology     2026-04-20
# 292     P100293  Patient_100293   51    Male        Cardiology     2026-05-27
# 311     P100312  Patient_100312   69  Female       Orthopedics     2026-05-21
# 435     P100436  Patient_100436   71  Female        Pediatrics     2026-08-02
# 454     P100455  Patient_100455   60  Female          Oncology     2026-06-21
# 484     P100485  Patient_100485   73  Female         Emergency     2026-05-21
# 524     P100525  Patient_100525   31    Male       Orthopedics     2026-04-16
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID               0
# Patient_Name             0
# Age                      0
# Gender                   0
# Department               0
# Admission_Date           0
# Discharge_Date           0
# Admission_Type           0
# Diagnosis                0
# Treatment                0
# Doctor                   0
# Hospital_Branch          0
# Insurance_Type          25
# Treatment_Cost           0
# Length_of_Stay           0
# Patient_Satisfaction    25
# Outcome                  0
# Age_Group                0
# Admission_Month          0
# Admission_Month_Num      0
# Admission_Week           0
# Day_of_Week              0
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# Patient_ID              0.0
# Patient_Name            0.0
# Age                     0.0
# Gender                  0.0
# Department              0.0
# Admission_Date          0.0
# Discharge_Date          0.0
# Admission_Type          0.0
# Diagnosis               0.0
# Treatment               0.0
# Doctor                  0.0
# Hospital_Branch         0.0
# Insurance_Type          0.5
# Treatment_Cost          0.0
# Length_of_Stay          0.0
# Patient_Satisfaction    0.5
# Outcome                 0.0
# Age_Group               0.0
# Admission_Month         0.0
# Admission_Month_Num     0.0
# Admission_Week          0.0
# Day_of_Week             0.0
# dtype: float64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Patient_ID    Patient_Name  Age  Gender        Department Admission_Date  \
# 6       P100007  Patient_100007   57  Female         Neurology     2026-07-20
# 123     P100124  Patient_100124   79  Female         Maternity     2026-08-16
# 152     P100153  Patient_100153   64  Female  General Medicine     2026-06-01
# 155     P100156  Patient_100156   74  Female          Oncology     2026-05-09
# 243     P100244  Patient_100244   42    Male        Cardiology     2026-04-20
# 292     P100293  Patient_100293   51    Male        Cardiology     2026-05-27
# 311     P100312  Patient_100312   69  Female       Orthopedics     2026-05-21
# 435     P100436  Patient_100436   71  Female        Pediatrics     2026-08-02
# 454     P100455  Patient_100455   60  Female          Oncology     2026-06-21
# 484     P100485  Patient_100485   73  Female         Emergency     2026-05-21
# 524     P100525  Patient_100525   31    Male       Orthopedics     2026-04-16
# ...

# %%
df["Insurance_Type"] = df["Insurance_Type"].fillna("Unknown")

# %%
df["Insurance_Type"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Patient_Satisfaction"].median()
# Out:
# np.float64(3.9)

# %%
df["Patient_Satisfaction"] = df["Patient_Satisfaction"].fillna(
    df["Patient_Satisfaction"].median()
)

# %%
df["Patient_Satisfaction"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Patient_ID              0
# Patient_Name            0
# Age                     0
# Gender                  0
# Department              0
# Admission_Date          0
# Discharge_Date          0
# Admission_Type          0
# Diagnosis               0
# Treatment               0
# Doctor                  0
# Hospital_Branch         0
# Insurance_Type          0
# Treatment_Cost          0
# Length_of_Stay          0
# Patient_Satisfaction    0
# Outcome                 0
# Age_Group               0
# Admission_Month         0
# Admission_Month_Num     0
# Admission_Week          0
# Day_of_Week             0
# dtype: int64

# %%
df["Age"].min()
# Out:
# np.int64(1)

# %%
df["Age"].max()
# Out:
# np.int64(90)

# %%
df["Age"].describe()
# Out:
# count    5000.000000
# mean       45.924000
# std        19.498602
# min         1.000000
# 25%        32.000000
# 50%        46.000000
# 75%        59.000000
# max        90.000000
# Name: Age, dtype: float64

# %%
df[(df["Age"] < 0) | (df["Age"] > 100)]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Patient_Name, Age, Gender, Department, Admission_Date, Discharge_Date, Admission_Type, Diagnosis, Treatment, Doctor, Hospital_Branch, Insurance_Type, Treatment_Cost, Length_of_Stay, Patient_Satisfaction, Outcome, Age_Group, Admission_Month, Admission_Month_Num, Admission_Week, Day_of_Week]
# Index: []

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      2688
# Female    2312
# Name: count, dtype: int64

# %%
df["Gender"].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df["Department"].value_counts()
# Out:
# Department
# Emergency           863
# General Medicine    798
# Pediatrics          618
# Cardiology          562
# Orthopedics         499
# Surgery             491
# Maternity           447
# Neurology           408
# Oncology            314
# Name: count, dtype: int64

# %%
df["Doctor"].value_counts()
# Out:
# Doctor
# Dr. Imran     543
# Dr. Usman     521
# Dr. Sana      518
# Dr. Bilal     499
# Dr. Fatima    498
# Dr. Ayesha    495
# Dr. Maryam    492
# Dr. Hassan    487
# Dr. Ahmed     483
# Dr. Zainab    464
# Name: count, dtype: int64

# %%
df[
    (df["Patient_Satisfaction"] < 1) |
    (df["Patient_Satisfaction"] > 5)
]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Patient_Name, Age, Gender, Department, Admission_Date, Discharge_Date, Admission_Type, Diagnosis, Treatment, Doctor, Hospital_Branch, Insurance_Type, Treatment_Cost, Length_of_Stay, Patient_Satisfaction, Outcome, Age_Group, Admission_Month, Admission_Month_Num, Admission_Week, Day_of_Week]
# Index: []

# %%
df[(df["Age"] < 0) | (df["Age"] > 100)]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Patient_Name, Age, Gender, Department, Admission_Date, Discharge_Date, Admission_Type, Diagnosis, Treatment, Doctor, Hospital_Branch, Insurance_Type, Treatment_Cost, Length_of_Stay, Patient_Satisfaction, Outcome, Age_Group, Admission_Month, Admission_Month_Num, Admission_Week, Day_of_Week]
# Index: []

# %%
df["Treatment_Cost"].value_counts()
# Out:
# Treatment_Cost
# 59967.13     2
# 18736.66     2
# 50322.48     1
# 56368.49     1
# 30822.28     1
#             ..
# 33902.05     1
# 36255.42     1
# 43300.85     1
# 26535.95     1
# 224902.54    1
# Name: count, Length: 4998, dtype: int64

# %%
 df[df["Treatment_Cost"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Patient_Name, Age, Gender, Department, Admission_Date, Discharge_Date, Admission_Type, Diagnosis, Treatment, Doctor, Hospital_Branch, Insurance_Type, Treatment_Cost, Length_of_Stay, Patient_Satisfaction, Outcome, Age_Group, Admission_Month, Admission_Month_Num, Admission_Week, Day_of_Week]
# Index: []

# %%
df[df["Treatment_Cost"] <= 0].shape
# Out:
# (0, 22)

# %%
df.nlargest(10, "Treatment_Cost")[
    ["Patient_ID", "Department", "Treatment", "Treatment_Cost"]
]
# Out:
#      Patient_ID   Department     Treatment  Treatment_Cost
# 2924    P102925   Cardiology       Surgery       264100.49
# 3040    P103041   Cardiology       Surgery       258721.69
# 3999    P104000      Surgery       Surgery       257000.04
# 4851    P104852   Cardiology       Surgery       252254.17
# 2073    P102074     Oncology       Surgery       251840.06
# 598     P100599      Surgery       Surgery       247283.63
# 1290    P101291  Orthopedics       Surgery       245659.50
# 219     P100220    Neurology  Chemotherapy       243069.83
# 1210    P101211    Neurology       Surgery       242720.90
# 733     P100734     Oncology       Surgery       240870.99

# %%
df["Length_of_Stay"].describe()
# Out:
# count    5000.000000
# mean        4.371600
# std         2.744781
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        22.000000
# Name: Length_of_Stay, dtype: float64

# %%
df[df["Length_of_Stay"] < 0]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Patient_Name, Age, Gender, Department, Admission_Date, Discharge_Date, Admission_Type, Diagnosis, Treatment, Doctor, Hospital_Branch, Insurance_Type, Treatment_Cost, Length_of_Stay, Patient_Satisfaction, Outcome, Age_Group, Admission_Month, Admission_Month_Num, Admission_Week, Day_of_Week]
# Index: []

# %%
df.nlargest(10, "Length_of_Stay")[
    ["Patient_ID", "Department", "Admission_Date",
     "Discharge_Date", "Length_of_Stay"]
]
# Out:
#      Patient_ID  Department Admission_Date Discharge_Date  Length_of_Stay
# 219     P100220   Neurology     2026-04-03     2026-04-25              22
# 1979    P101980  Pediatrics     2026-04-26     2026-05-18              22
# 678     P100679   Neurology     2026-08-02     2026-08-23              21
# 581     P100582  Pediatrics     2026-05-29     2026-06-18              20
# 1494    P101495   Neurology     2026-05-30     2026-06-19              20
# 2008    P102009  Pediatrics     2026-08-10     2026-08-30              20
# 279     P100280  Pediatrics     2026-05-11     2026-05-30              19
# 1987    P101988   Neurology     2026-07-23     2026-08-11              19
# 96      P100097   Emergency     2026-04-21     2026-05-09              18
# 668     P100669   Neurology     2026-07-15     2026-08-01              17

# %%
df[df["Discharge_Date"] < df["Admission_Date"]]
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Patient_Name, Age, Gender, Department, Admission_Date, Discharge_Date, Admission_Type, Diagnosis, Treatment, Doctor, Hospital_Branch, Insurance_Type, Treatment_Cost, Length_of_Stay, Patient_Satisfaction, Outcome, Age_Group, Admission_Month, Admission_Month_Num, Admission_Week, Day_of_Week]
# Index: []

# %%
df[["Admission_Date", "Discharge_Date"]].dtypes
# Out:
# Admission_Date    str
# Discharge_Date    str
# dtype: object

# %%
df["Admission_Date"] = pd.to_datetime(df["Admission_Date"])
df["Discharge_Date"] = pd.to_datetime(df["Discharge_Date"])

# %%
calculated_stay = (
    df["Discharge_Date"] - df["Admission_Date"]
).dt.days

# %%
(df["Length_of_Stay"] != calculated_stay).sum()
# Out:
# np.int64(0)

# %%
Length_of_Stay = 22

# %%
df["Department"].value_counts()
# Out:
# Department
# Emergency           863
# General Medicine    798
# Pediatrics          618
# Cardiology          562
# Orthopedics         499
# Surgery             491
# Maternity           447
# Neurology           408
# Oncology            314
# Name: count, dtype: int64

# %%
department_analysis = (
    df["Department"]
    .value_counts()
    .reset_index()
)

department_analysis.columns = ["Department", "Patient_Count"]

department_analysis
# Out:
#          Department  Patient_Count
# 0         Emergency            863
# 1  General Medicine            798
# 2        Pediatrics            618
# 3        Cardiology            562
# 4       Orthopedics            499
# 5           Surgery            491
# 6         Maternity            447
# 7         Neurology            408
# 8          Oncology            314

# %%
df["Department"].value_counts()
# Out:
# Department
# Emergency           863
# General Medicine    798
# Pediatrics          618
# Cardiology          562
# Orthopedics         499
# Surgery             491
# Maternity           447
# Neurology           408
# Oncology            314
# Name: count, dtype: int64

# %%
department_analysis = (
    df["Department"]
    .value_counts()
    .reset_index()
)

# %%
department_analysis.columns = [
    "Department",
    "Patient_Count"
]

# %%
department_analysis
# Out:
#          Department  Patient_Count
# 0         Emergency            863
# 1  General Medicine            798
# 2        Pediatrics            618
# 3        Cardiology            562
# 4       Orthopedics            499
# 5           Surgery            491
# 6         Maternity            447
# 7         Neurology            408
# 8          Oncology            314

# %%
department_analysis["Percentage"] = (
    department_analysis["Patient_Count"]
    / len(df) * 100
).round(2)

# %%
department_analysis
# Out:
#          Department  Patient_Count  Percentage
# 0         Emergency            863       17.26
# 1  General Medicine            798       15.96
# 2        Pediatrics            618       12.36
# 3        Cardiology            562       11.24
# 4       Orthopedics            499        9.98
# 5           Surgery            491        9.82
# 6         Maternity            447        8.94
# 7         Neurology            408        8.16
# 8          Oncology            314        6.28

# %%
df["Admission_Type"].value_counts()
# Out:
# Admission_Type
# Emergency    1925
# Elective     1815
# Urgent       1260
# Name: count, dtype: int64

# %%
admission_analysis = (
    df["Admission_Type"]
    .value_counts()
    .reset_index()
)

admission_analysis.columns = [
    "Admission_Type",
    "Patient_Count"
]

admission_analysis
# Out:
#   Admission_Type  Patient_Count
# 0      Emergency           1925
# 1       Elective           1815
# 2         Urgent           1260

# %%
admission_analysis["Percentage"] = (
    admission_analysis["Patient_Count"]
    / len(df) * 100
).round(2)

# %%
admission_analysis
# Out:
#   Admission_Type  Patient_Count  Percentage
# 0      Emergency           1925        38.5
# 1       Elective           1815        36.3
# 2         Urgent           1260        25.2

# %%
department_admission = pd.crosstab(
    df["Department"],
    df["Admission_Type"]
)

department_admission
# Out:
# Admission_Type    Elective  Emergency  Urgent
# Department
# Cardiology             196        228     138
# Emergency              320        339     204
# General Medicine       306        280     212
# Maternity              158        162     127
# Neurology              151        156     101
# Oncology               113        121      80
# Orthopedics            173        206     120
# Pediatrics             230        238     150
# Surgery                168        195     128

# %%
department_admission["Total"] = department_admission.sum(axis=1)

department_admission
# Out:
# Admission_Type    Elective  Emergency  Urgent  Total
# Department
# Cardiology             196        228     138    562
# Emergency              320        339     204    863
# General Medicine       306        280     212    798
# Maternity              158        162     127    447
# Neurology              151        156     101    408
# Oncology               113        121      80    314
# Orthopedics            173        206     120    499
# Pediatrics             230        238     150    618
# Surgery                168        195     128    491

# %%
department_admission = pd.crosstab(
    df["Department"],
    df["Admission_Type"]
)

department_admission["Total"] = department_admission.sum(axis=1)

department_admission
# Out:
# Admission_Type    Elective  Emergency  Urgent  Total
# Department
# Cardiology             196        228     138    562
# Emergency              320        339     204    863
# General Medicine       306        280     212    798
# Maternity              158        162     127    447
# Neurology              151        156     101    408
# Oncology               113        121      80    314
# Orthopedics            173        206     120    499
# Pediatrics             230        238     150    618
# Surgery                168        195     128    491

# %%
department_admission["Emergency_Rate"] = (
    department_admission["Emergency"]
    / department_admission["Total"]
    * 100
).round(2)

# %%
department_admission
# Out:
# Admission_Type    Elective  Emergency  Urgent  Total  Emergency_Rate
# Department
# Cardiology             196        228     138    562           40.57
# Emergency              320        339     204    863           39.28
# General Medicine       306        280     212    798           35.09
# Maternity              158        162     127    447           36.24
# Neurology              151        156     101    408           38.24
# Oncology               113        121      80    314           38.54
# Orthopedics            173        206     120    499           41.28
# Pediatrics             230        238     150    618           38.51
# Surgery                168        195     128    491           39.71

# %%
department_admission.sort_values(
    "Emergency_Rate",
    ascending=False
)
# Out:
# Admission_Type    Elective  Emergency  Urgent  Total  Emergency_Rate
# Department
# Orthopedics            173        206     120    499           41.28
# Cardiology             196        228     138    562           40.57
# Surgery                168        195     128    491           39.71
# Emergency              320        339     204    863           39.28
# Oncology               113        121      80    314           38.54
# Pediatrics             230        238     150    618           38.51
# Neurology              151        156     101    408           38.24
# Maternity              158        162     127    447           36.24
# General Medicine       306        280     212    798           35.09

# %%
diagnosis_analysis = (
    df["Diagnosis"]
    .value_counts()
    .reset_index()
)

diagnosis_analysis.columns = [
    "Diagnosis",
    "Patient_Count"
]

diagnosis_analysis
# Out:
#                Diagnosis  Patient_Count
# 0        Routine Checkup            676
# 1          Heart Disease            615
# 2           Hypertension            615
# 3  Respiratory Infection            586
# 4               Diabetes            550
# 5               Fracture            473
# 6              Pregnancy            436
# 7           Appendicitis            389
# 8                 Cancer            339
# 9                 Stroke            321

# %%
diagnosis_analysis["Percentage"] = (
    diagnosis_analysis["Patient_Count"]
    / len(df) * 100
).round(2)

# %%
diagnosis_analysis
# Out:
#                Diagnosis  Patient_Count  Percentage
# 0        Routine Checkup            676       13.52
# 1          Heart Disease            615       12.30
# 2           Hypertension            615       12.30
# 3  Respiratory Infection            586       11.72
# 4               Diabetes            550       11.00
# 5               Fracture            473        9.46
# 6              Pregnancy            436        8.72
# 7           Appendicitis            389        7.78
# 8                 Cancer            339        6.78
# 9                 Stroke            321        6.42

# %%
top_5_diagnoses = diagnosis_analysis.head(5)

top_5_diagnoses
# Out:
#                Diagnosis  Patient_Count  Percentage
# 0        Routine Checkup            676       13.52
# 1          Heart Disease            615       12.30
# 2           Hypertension            615       12.30
# 3  Respiratory Infection            586       11.72
# 4               Diabetes            550       11.00

# %%
diagnosis_analysis.tail(5)
# Out:
#       Diagnosis  Patient_Count  Percentage
# 5      Fracture            473        9.46
# 6     Pregnancy            436        8.72
# 7  Appendicitis            389        7.78
# 8        Cancer            339        6.78
# 9        Stroke            321        6.42

# %%
total_cost = df["Treatment_Cost"].sum()

total_cost
# Out:
# np.float64(354705476.40999997)

# %%
f"${total_cost:,.2f}"
# Out:
# '$354,705,476.41'

# %%
average_cost = df["Treatment_Cost"].mean()

average_cost
# Out:
# np.float64(70941.095282)

# %%
department_financial = (
    df.groupby("Department")["Treatment_Cost"]
    .agg(["sum", "mean", "count"])
    .reset_index()
)

# %%
department_financial
# Out:
#          Department          sum          mean  count
# 0        Cardiology  46428271.16  82612.582135    562
# 1         Emergency  62358852.05  72258.229490    863
# 2  General Medicine  47562489.98  59602.117769    798
# 3         Maternity  28806426.04  64443.906130    447
# 4         Neurology  31907815.62  78205.430441    408
# 5          Oncology  27143447.83  86444.101369    314
# 6       Orthopedics  34328862.78  68795.316192    499
# 7        Pediatrics  35932540.54  58143.269482    618
# 8           Surgery  40236770.41  81948.615906    491

# %%
treatment_financial = (
    df.groupby("Treatment")["Treatment_Cost"]
    .agg(["sum", "mean", "count"])
    .reset_index()
)

# %%
treatment_financial.columns = [
    "Treatment",
    "Total_Cost",
    "Average_Cost",
    "Patient_Count"
]

# %%
treatment_financial.sort_values(
    "Total_Cost",
    ascending=False
)
# Out:
#               Treatment    Total_Cost   Average_Cost  Patient_Count
# 6               Surgery  1.197130e+08  157517.165289            760
# 3            Medication  6.065160e+07   40007.651860           1516
# 2  Diagnostic Procedure  4.902907e+07   57276.953376            856
# 0          Chemotherapy  3.440453e+07  124654.097862            276
# 5         Physiotherapy  3.324889e+07   52360.463465            635
# 1              Delivery  3.078706e+07   90817.277021            339
# 4           Observation  2.687128e+07   43481.029547            618

# %%
department_financial = (
    df.groupby("Department")["Treatment_Cost"]
    .agg(["sum", "mean", "count"])
    .reset_index()
)

# %%
department_financial.columns = [
    "Department",
    "Total_Cost",
    "Average_Cost",
    "Patient_Count"
]

# %%
department_financial
# Out:
#          Department   Total_Cost  Average_Cost  Patient_Count
# 0        Cardiology  46428271.16  82612.582135            562
# 1         Emergency  62358852.05  72258.229490            863
# 2  General Medicine  47562489.98  59602.117769            798
# 3         Maternity  28806426.04  64443.906130            447
# 4         Neurology  31907815.62  78205.430441            408
# 5          Oncology  27143447.83  86444.101369            314
# 6       Orthopedics  34328862.78  68795.316192            499
# 7        Pediatrics  35932540.54  58143.269482            618
# 8           Surgery  40236770.41  81948.615906            491

# %%
department_financial = department_financial.sort_values(
    "Total_Cost",
    ascending=False
)

department_financial
# Out:
#          Department   Total_Cost  Average_Cost  Patient_Count
# 1         Emergency  62358852.05  72258.229490            863
# 2  General Medicine  47562489.98  59602.117769            798
# 0        Cardiology  46428271.16  82612.582135            562
# 8           Surgery  40236770.41  81948.615906            491
# 7        Pediatrics  35932540.54  58143.269482            618
# 6       Orthopedics  34328862.78  68795.316192            499
# 4         Neurology  31907815.62  78205.430441            408
# 3         Maternity  28806426.04  64443.906130            447
# 5          Oncology  27143447.83  86444.101369            314

# %%
department_financial.columns
# Out:
# Index(['Department', 'Total_Cost', 'Average_Cost', 'Patient_Count'], dtype='str')

# %%
df["Admission_Date"] = pd.to_datetime(df["Admission_Date"])
df["Discharge_Date"] = pd.to_datetime(df["Discharge_Date"])

# %%
dashboard_summary = df.copy()

# %%
dashboard_summary.to_csv(
    "Hospital_Dashboard_Cleaned.csv",
    index=False
)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\AM HK'
